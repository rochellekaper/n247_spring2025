# %% [markdown]
# Just what variables exist where?  That's what we mean by "scope".  Variables at the "top level" (leftmost indent) are "global" and can be seen anywhere.  Variables inside functions are "local" and live only in those functions.  So, an `i` inside of one function is wholly separate from an `i` inside another function.
#
# Inside a function, by default, if you access a global variable, it makes a local copy of that variable so that it starts off with the global value but changes to it remain local (use the `global` keyword if you want to change the global one).
#
# Run this and then open up a Scratch window to try out these functions.

# %%
from IPython.core.debugger import set_trace

g=900

def funcA(i):
    j=100
    return i+j
    
def funcB(input):
    i=10
    j=11
    return i+j+input+g

def funcC(input):  
    global g  # What happens if we comment out this line?
    g=800
    return input+g

def funcD(i):
    i=6
    foo=[i*i for i in range(i)]
    print('foo is now: ', foo)
    for i in range(i):
        print(i)
    print(i)

def funcE():
    print (g)
      
def funcF(rad):
    return(3.14*2*rad, 3.14*rad*rad)
    
# g=1000
    
if __name__ == '__main__':
    #set_trace()
    print('g is now ', g)
    a=funcA(100)
    print('a is now ', a)
    b=funcB(200)
    print('b is now ', b)
    c=funcC(300)
    print('c is now ', c)
    b=funcB(200)
    print('b is now ', b, ' and g is now ',g )
    i=766;
    j=234;
    k=funcB(200)
    l=funcA(100)
    funcD(3)
    f=funcF(243)
# Out:
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/lib/python3.7/bdb.py", line 332, in set_trace
#     sys.settrace(self.trace_dispatch)
# g is now  900
# a is now  200
# b is now  1121
# c is now  1100
# b is now  1021  and g is now  800
# > <ipython-input-1-03e5c6895844>(21)funcD()
#      19 def funcD(i):
#      20     set_trace()
# ---> 21     i=6
#      22     foo=[i*i for i in range(i)]
#      23     print('foo is now: ', foo)
#
# ipdb> print(i)
# 3
# ipdb> n
# > <ipython-input-1-03e5c6895844>(22)funcD()
#      20     set_trace()
#      21     i=6
# ---> 22     foo=[i*i for i in range(i)]
#      23     print('foo is now: ', foo)
#      24     for i in range(i):
#
# ipdb> print(i)
# 6
# ipdb> n
# > <ipython-input-1-03e5c6895844>(23)funcD()
#      21     i=6
#      22     foo=[i*i for i in range(i)]
# ---> 23     print('foo is now: ', foo)
#      24     for i in range(i):
#      25         print(i)
#
# ipdb> i
# 6
# ipdb> c
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/lib/python3.7/bdb.py", line 343, in set_continue
#     sys.settrace(None)
# foo is now:  [0, 1, 4, 9, 16, 25]
# 0
# 1
# 2
# 3
# 4
# 5
# 5

# %%
_t
